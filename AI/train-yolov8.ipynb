# %% [markdown]
# # Set the absolute path to the datasets folder

# %%
import os
DATASETS_FOLDER_ABSOLUTE_PATH = f"C:/Users/{os.getenv('USERNAME')}/Documents/AMROPick/AI/datasets"

# %% [markdown]
# ## Train OBB

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("models/yolov8n-obb.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data=f"{DATASETS_FOLDER_ABSOLUTE_PATH}/data-obb.yaml", epochs=100, imgsz=1024, agnostic_nms=True)

# %% [markdown]
# ## Train detect

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("models/yolov8n.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data=f"{DATASETS_FOLDER_ABSOLUTE_PATH}/data-detect.yaml", epochs=100, imgsz=640, agnostic_nms=True)

# %% [markdown]
# ## Train classify

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("models/yolov8n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data=f"{DATASETS_FOLDER_ABSOLUTE_PATH}/classify", epochs=100, imgsz=640)
