# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tbyiCptX7yH7KgeZtmAu")
project = rf.workspace("defectdetection-w2xhs").project("metal-tubes-utzul")
version = project.version(4)
dataset = version.download("yolov12")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 49.6 MB/s eta 0:00:0031m62.1 MB/s eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 8.9 MB/s eta 0:00:00 MB/s eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.0 MB/s eta 0:00:0031m11.3 MB/s eta 0:00:01
# ...
#   Attempting uninstall: idna━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#     Found existing installation: idna 3.10╺━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#     Uninstalling idna-3.10:━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#       Successfully uninstalled idna-3.10m╺━━━━━━━━━━━━━━━━━━━ 4/8 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [roboflow]0m 4/8 [opencv-python-headless]
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to plates-segmentation-16 in yolov12:: 100%|███████| 556/556 [00:00<00:00, 4611.02it/s]

# %%
# !yolo train \
  data=/data/corob/datasets/metal-tubes.v4i.yolov12/data.yaml \
  model=runs/segment/train11/weights/best.pt \
  batch=1 \
  imgsz=1024 \
  device=0 \
  epochs=300 \
  patience=300 \
  overlap_mask=False
# Out:
# New https://pypi.org/project/ultralytics/8.3.222 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3080, 9885MiB)
# ...
